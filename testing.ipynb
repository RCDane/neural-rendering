# %%
import drjit as dr
import drjit.nn as nn

vec1 = dr.auto.ad.Array2f([1,2])
vec2 = dr.auto.ad.Array3f([1,2,3])
f1 = dr.auto.ad.Float(1.0)

coop = nn.CoopVec(*vec1, *vec2)
coop
# Out:
# drjit.nn.CoopVec[drjit.cuda.ad.Float, shape=(5, 1)]
